# %% [markdown]
# ![](../images/linkedlist_definition.png)

# %% [markdown]
# 链表的组成单位是节点（node）对象。每个节点都包含两项数据：节点的“值”和指向下一节点的“引用”。
#
# 链表的首个节点被称为“头节点”，最后一个节点被称为“尾节点”。
# 尾节点指向的是“空”，它在 Java、C++ 和 Python 中分别被记为 null、nullptr 和 None 。
# 在 C、C++、Go 和 Rust 等支持指针的语言中，上述“引用”应被替换为“指针”。

# %% [markdown]
# 链表常用操作

# %% [markdown]
# 初始化链表

# %%
from operator import index
from traceback import print_list


class ListNode:
    def __init__(self,val):
        self.val = val
        self.next = None

if __name__ == "__main__":
    n0 = ListNode(0)
    n1 = ListNode(1)
    n2 = ListNode(2)
    n3 = ListNode(3)
    n4 = ListNode(4)
    #构建结点之间的引用
    n0.next = n1
    n1.next = n2
    n2.next = n3
    n3.next = n4

# %% [markdown]
# ![](../images/linkedlist_insert_node.png)

# %%
class ListNode:
    def __init__ (self,val):
        self.val = val
        self.next = None

    def insert(n0 , p):
        n1 = n0.next
        p.next = n1
        n0.next = p

def print_list(self):
    current = self
    while current:
        print(current.val, end=" -> ")
        current = current.next
    print("None")

if __name__ == "__main__":
    n0 = ListNode(0)
    n1 = ListNode(1)
    n2 = ListNode(2)
    n3 = ListNode(3)
    n4 = ListNode(4)
    #构建结点之间的引用
    n0.next = n1
    n1.next = n2
    n2.next = n3
    n3.next = n4

    print_list(n0)
# Out:
# 0 -> 1 -> 2 -> 3 -> 4 -> None

# %% [markdown]
# ![](../images/linkedlist_remove_node.png)

# %%
class ListNode:
    def __init__ (self,val):
        self.val = val
        self.next = None

if __name__ == "__main__":
    n0 = ListNode(5)
    n1 = ListNode(4)
    n2 = ListNode(3)
    n3 = ListNode(2)
    n4 = ListNode(2)
    #构建结点之间的引用
    n0.next = n1
    n1.next = n2
    n2.next = n3
    n3.next = n4

    # 遍历链表并打印所有数据
    def print_linked_list(head):
        current = head
        values = []
        while current is not None:
            values.append(current.val)
            current = current.next
        print(" -> ".join(map(str, values)))
    
    # 调用函数打印链表
    print("链表中的所有数据:")
    print_linked_list(n0)
# Out:
# 链表中的所有数据:
# 5 -> 4 -> 3 -> 2 -> 2

# %% [markdown]
# ![](../images/linkedlist_common_types.png)
