# %% [markdown]
# 搜索算法可根据实现思路分为以下两类。
#
# 1.通过遍历数据结构来定位目标元素，例如数组、链表、树和图的遍历等。
#
# 2.利用数据组织结构或数据包含的先验信息，实现高效元素查找，例如二分查找、哈希查找和二叉搜索树查找等。

# %% [markdown]
# ![image.png](attachment:d3d21a9d-3b88-4f47-964f-81a6061b1c70.png)

# %% [markdown]
# ![image.png](attachment:36397b76-7af1-4004-986b-c075a66ee99c.png)
