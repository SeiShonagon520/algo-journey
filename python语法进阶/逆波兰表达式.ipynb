# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 逆波兰表达式
def eval_rpn(tokens):
    stack = []
    ops = {
        '+': lambda a, b: a + b,
        '-': lambda a, b: a - b,
        '*': lambda a, b: a * b,
        '/': lambda a, b: int(a / b),
    }

    for i in range(tokens):
        if i in ops:
            b = stack.pop()
            a = stack.pop()
            stack.append(ops[t](a,b))
        else:
            stack.append
